# %%
print("my first program")
# Out:
# my first program

# %%
#hi my name is swetha          #this is single line comment

# %%
"""vardhaman college
electronics 
swetha
engineeering
power bi"""
#triple quote("")at begininng and end of the line
# Out:
# 'vardhaman college\nelectronics \nswetha\nengineeering\npower bi'

# %%
print("asdfghjh")
#print("qwertyy")
print("zxcvb")
print("kjjhg")
# Out:
# asdfghjh
# zxcvb
# kjjhg

# %%
a=10
b=20

# %%
a
# Out:
# 10

# %%
a=3456

# %%
a
# Out:
# 3456

# %%
var=23

# %%
var
# Out:
# 23

# %% [markdown]
# ![Pyhton%20Keywords.png](attachment:Pyhton%20Keywords.png)

# %%
None=12  #default none  is a function we cannotn assign value
# Out:
#   Input In [14]
#     None=12
#     ^
# SyntaxError: cannot assign to None

# %%
1a=29
# Out:
#   Input In [15]
#     1a=29
#      ^
# SyntaxError: invalid syntax

# %%
a1=21

# %%
a1
# Out:
# 21

# %%
a^x=34
# Out:
#   Input In [18]
#     a^x=34
#     ^
# SyntaxError: cannot assign to operator

# %%
_ab=56

# %%
_ab
# Out:
# 56

# %%
type(_ab)
# Out:
# int

# %%
int a=12
# Out:
#   Input In [1]
#     int a=12
#         ^
# SyntaxError: invalid syntax

# %%
 var=13

# %%
c=23.3

# %%
type(c)
# Out:
# float

# %%
a="swetha"

# %%
a
# Out:
# 'swetha'

# %%
type(a) #fuction to know datatype
# Out:
# str

# %%
b='235  asd'

# %%
b
# Out:
# '235  asd'

# %%
print(b)
# Out:
# 235  asd

# %%
print(a)
# Out:
# swetha

# %%
type(b)
# Out:
# str

# %%
a=456
b="asdf"

# %%
a,b=12 ,"ghj" #we can create multiple variables in single line

# %%
a,b,c=12 ,"ghj" ,"wer"

# %%
b
# Out:
# 'ghj'

# %%
print(c)
# Out:
# wer

# %%
type(c)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
a,b,c  #will get output as tuples
# Out:
# (12, 'ghj', 'wer')

# %%
print(a,b,c)
# Out:
# 12 ghj wer

# %%
a=1.45

# %%
type(a)
# Out:
# float

# %%
b=True
c=False

# %%
type(b)
# Out:
# bool

# %%
print(True+True+True+False+True)
# Out:
# 4

# %%
print(False-True+True)
# Out:
# 0

# %%
m=34+26j

# %%
m.imag
# Out:
# 26.0

# %%
type(m)
# Out:
# complex

# %%
a=23
b=34
c=45

# %%
a*b
# Out:
# 782

# %%
a+b
# Out:
# 57

# %%
a-b
# Out:
# -11

# %%
d,e="swe" ,"abhi"

# %%
a+d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 a+d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#type casting
str(67)
# Out:
# '67'

# %%
g=str(a)

# %%
h= "abc"

# %%
g+h
# Out:
# '12abc'

# %%
f=str(a)+"jan"

# %%
f
# Out:
# '12jan'

# %%
type(f)
# Out:
# str
